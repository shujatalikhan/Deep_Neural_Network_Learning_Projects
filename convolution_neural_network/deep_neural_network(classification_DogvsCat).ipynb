# %%
# !ls
# Out:
#  kagglecatsanddogs_3367a.zip   PetImages        sample_data   y.pickle
# 'MSR-LA - 3467.docx'	      'readme[1].txt'   X.pickle

# %%
# !unzip kagglecatsanddogs_3367a.zip

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
datadir="PetImages" #The largest issue is not all of these images are the same size.

# %%
categories=['Dog','Cat']


for category in categories:# do dogs and cats
  path=os.path.join(datadir,category)# create path to dogs and cats
  for img in os.listdir(path):# iterate over each image per dogs and cats
    img_array=cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)# convert to array
    plt.imshow(img_array, cmap="gray")# graph it
    plt.show()
    break # we just want one for now so break
  break#...and one more!

# %%
print(img_array)
# Out:
# [[89 90 91 ... 91 90 89]
#  [89 90 91 ... 91 90 89]
#  [90 91 92 ... 92 90 89]
#  ...
#  [16 15 14 ... 13 13 13]
#  [15 14 14 ... 13 13 13]
#  [13 13 13 ... 13 13 13]]

# %% [markdown]
# 371 tall, 500 wide, and 3-channel image. 3-channel is because it's RGB (color). We definitely don't want the images that big, but also various images are different shapes, and this is also a problem.

# %%
print(img_array.shape)
# Out:
# (371, 500)

# %%
IMG_SIZE=100

new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
plt.imshow(new_array,cmap="gray")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
training_data =[]

def create_training_data():
  for category in categories:
    path=os.path.join(datadir,category)
    class_num = categories.index(category)# get the classification  (0 or a 1). 0=dog 1=cat
    for img in os.listdir(path): # iterate over each image per dogs and cats
      try:
        img_array=cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE) # convert to array
        new_array=cv2.resize(img_array,(IMG_SIZE, IMG_SIZE))# resize to normalize data size
        training_data.append([new_array,class_num])# add this to our training_data
      except Exception as e:# in the interest in keeping the output clean...
        pass
create_training_data()

# %%
print(training_data[:10])
# Out:
# [[array([[ 91,  89,  95, ..., 101,  96,  91],
#        [ 94,  92,  96, ..., 102,  99,  93],
#        [ 96,  91,  99, ..., 101,  99,  94],
#        ...,
#        [ 13,  20,  18, ...,  14,  14,  13],
#        [ 14,  18,  17, ...,  14,  14,  12],
#        [ 14,  14,  15, ...,  15,  13,  13]], dtype=uint8), 0], [array([[216, 149, 153, ..., 153, 152, 196],
#        [155, 124, 118, ..., 118, 117, 148],
#        [161, 119,  92, ...,  91, 120, 149],
#        ...,
#        [160, 120, 111, ...,  93, 122, 149],
#        [158, 118, 117, ..., 120, 122, 147],
#        [199, 139, 140, ..., 140, 139, 184]], dtype=uint8), 0], [array([[ 83,  84,  79, ..., 131, 136, 133],
#        [ 81,  84,  77, ..., 139, 130, 136],
#        [ 81,  82,  80, ..., 131, 137, 130],
#        ...,
#        [147, 145, 151, ..., 119, 114, 124],
#        [157, 150, 150, ..., 118, 120, 108],
#        [151, 142, 141, ..., 109, 111, 114]], dtype=uint8), 0], [array([[ 86, 159, 194, ..., 148, 143, 139],
#        [212, 139, 105, ..., 111, 137, 154],
#        [147, 145, 105, ..., 100, 143, 146],
#        ...,
#        [221, 109, 114, ...,  83,  28, 220],
#        [156, 151, 154, ...,  22, 210, 142],
#        [185, 239, 173, ...,  71, 206, 116]], dtype=uint8), 0], [array([[122, 126, 126, ...,  67,  64,  60],
#        [128, 138, 123, ...,  67,  64,  60],
#        [124, 138, 129, ...,  67,  64,  61],
#        ...,
#        [ 10,   8,   6, ..., 131, 128, 132],
#        [ 14,   9,   3, ..., 128, 132, 134],
#        [ 14,   7,   4, ..., 123, 131, 127]], dtype=uint8), 0], [array([[210, 212, 211, ...,  87,  93,  82],
#        [213, 209, 211, ...,  80,  85,  85],
#        [205, 217, 203, ...,  80,  81,  84],
#        ...,
#        [155, 152, 153, ..., 141, 142, 144],
#        [150, 146, 147, ..., 141, 142, 143],
#        [142, 146, 146, ..., 139, 137, 139]], dtype=uint8), 0], [array([[226, 217, 199, ..., 207, 207, 217],
#        [149, 132,  90, ..., 100, 101, 140],
#        [155, 121,  97, ..., 116, 105, 148],
#        ...,
#        [122,  57,  65, ...,  97,  97, 132],
#        [111,  73,  56, ...,  97,  87, 116],
#        [218, 201, 199, ..., 213, 211, 218]], dtype=uint8), 0], [array([[139, 144, 144, ...,  95,  96,  90],
#        [141, 144, 146, ...,  96,  96,  97],
#        [143, 145, 144, ..., 100,  96,  71],
#        ...,
#        [ 60,  58,  59, ...,  63,  66,  63],
#        [ 56,  58,  61, ...,  62,  63,  61],
#        [ 54,  58,  57, ...,  62,  61,  64]], dtype=uint8), 0], [array([[ 91,  91,  91, ..., 123, 123, 122],
#        [ 91,  91,  93, ..., 121, 122, 122],
#        [ 90,  92,  92, ..., 123, 121, 121],
#        ...,
#        [145, 152, 142, ..., 128, 138, 136],
#        [135, 150, 137, ..., 132, 134, 143],
#        [137, 143, 136, ..., 129, 127, 133]], dtype=uint8), 0], [array([[ 96,  64,  33, ...,  45,  45,  46],
#        [ 94,  30,  32, ...,  39,  47,  43],
#        [ 71,  34,  29, ...,  35,  48,  51],
#        ...,
#        [ 84,  85,  82, ..., 137, 135, 132],
#        [ 78,  77,  74, ..., 137, 135, 134],
#        [ 72,  72,  68, ..., 137, 135, 133]], dtype=uint8), 0]]

# %%
print(len(training_data))
# Out:
# 24946

# %% [markdown]
# Next, we want to shuffle the data. Right now our data is just all dogs, then all cats. This will usually wind up causing trouble too, as, initially, the classifier will learn to just predict dogs always. Then it will shift to oh, just predict all cats! Going back and forth like this is no good either.

# %%
import random

random.shuffle(training_data)

# %%
for sample in training_data[:10]:
  print(sample[1])
# Out:
# 0
# 1
# 0
# 1
# 0
# 0
# 0
# 0
# 1
# 0

# %%
X=[]
y=[]

# %%
for features,label in training_data:
  X.append(features)
  y.append(label)

X=np.array(X).reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %% [markdown]
# Let's save this data, so that we don't need to keep calculating it every time we want to play with the neural network model:

# %%
import pickle

pickle_out=open("X.pickle","wb")
pickle.dump(X,pickle_out)
pickle_out.close()

pickle_out=open("y.pickle","wb")
pickle.dump(y,pickle_out)
pickle_out.close()

# %% [markdown]
# We can always load it in to our current script, or a totally new one by doing:

# %%
pickle_in=open("X.pickle","rb")
X=pickle.load(pickle_in)

# %%
X[1]
# Out:
# array([[[ 56],
#         [ 55],
#         [ 58],
#         ...,
#         [234],
#         [231],
#         [233]],
#
#        [[ 60],
#         [ 61],
#         [ 63],
#         ...,
#         [235],
#         [234],
#         [230]],
#
#        [[ 66],
#         [ 67],
#         [ 67],
#         ...,
#         [237],
#         [234],
#         [234]],
#
#        ...,
#
#        [[154],
#         [173],
#         [165],
#         ...,
#         [ 60],
#         [ 59],
#         [ 59]],
#
#        [[177],
#         [167],
#         [178],
#         ...,
#         [ 59],
#         [ 59],
#         [ 57]],
#
#        [[172],
#         [159],
#         [174],
#         ...,
#         [ 59],
#         [ 59],
#         [ 57]]], dtype=uint8)

# %%
print(y[1])
# Out:
# 1

# %% [markdown]
# The Convolutional Neural Network gained popularity through its use with image data, and is currently the state of the art for detecting what an image is, or what is contained in the image.
#
# The basic CNN structure is as follows: Convolution -> Pooling -> Convolution -> Pooling -> Fully Connected Layer -> Output

# %% [markdown]
# Below is the code for convolution neural network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow .keras.layers import Dense,Dropout,Activation,Flatten,Conv2D,MaxPooling2D

import pickle

X=pickle.load(open("X.pickle","rb"))
y=pickle.load(open("y.pickle","rb"))

X=X/255

model=Sequential()
model.add(Conv2D(64,(3,3),input_shape=X.shape[1:]) )# defining of input shape is must in intial layer
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())# this converts our 3D feature maps to 1D feature vectors

model.add(Dense(64))
model.add(Activation('relu'))


model.add(Dense(1))
model.add(Activation('softmax'))
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

model.fit(X,y,batch_size=32,epochs=10,validation_split=0.1)

model.save('catvsdog.model')
# Out:
# Train on 22451 samples, validate on 2495 samples
# Epoch 1/10
# 22451/22451 [==============================] - 13s 582us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 2/10
# 22451/22451 [==============================] - 13s 580us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 3/10
# 22451/22451 [==============================] - 13s 569us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 4/10
# 22451/22451 [==============================] - 13s 563us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 5/10
# 22451/22451 [==============================] - 13s 564us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 6/10
# 22451/22451 [==============================] - 13s 568us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 7/10
# 22451/22451 [==============================] - 13s 577us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 8/10
# 22451/22451 [==============================] - 13s 566us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 9/10
# 22451/22451 [==============================] - 13s 566us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934
# Epoch 10/10
# 22451/22451 [==============================] - 13s 577us/sample - loss: 7.9573 - acc: 0.5009 - val_loss: 8.0766 - val_acc: 0.4934

# %% [markdown]
# # Analyzing Models with TensorBoard - Deep Learning

# %% [markdown]
# TensorBoard is a handy application that allows you to view aspects of your model, or models, in your browser.

# %% [markdown]
# * Con2d with 256

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time


NAME = "Cats-vs-dogs-CNN"

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))

model.add(Dense(1))
model.add(Activation('sigmoid'))

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'],
              )

model.fit(X, y,
          batch_size=32,
          epochs=10,
          validation_split=0.3,
          callbacks=[tensorboard])
# Out:
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 40s 2ms/sample - loss: 0.7133 - acc: 0.6071 - val_loss: 0.6320 - val_acc: 0.6489
# Epoch 2/10
# 17462/17462 [==============================] - 39s 2ms/sample - loss: 0.5956 - acc: 0.6925 - val_loss: 0.5861 - val_acc: 0.6956
# Epoch 3/10
# 17462/17462 [==============================] - 39s 2ms/sample - loss: 0.5641 - acc: 0.7141 - val_loss: 0.5621 - val_acc: 0.7154
# Epoch 4/10
# 17462/17462 [==============================] - 38s 2ms/sample - loss: 0.5298 - acc: 0.7391 - val_loss: 0.5830 - val_acc: 0.7091
# Epoch 5/10
# 17462/17462 [==============================] - 39s 2ms/sample - loss: 0.4950 - acc: 0.7570 - val_loss: 0.5229 - val_acc: 0.7465
# Epoch 6/10
# 17462/17462 [==============================] - 38s 2ms/sample - loss: 0.4645 - acc: 0.7823 - val_loss: 0.4960 - val_acc: 0.7636
# Epoch 7/10
# 17462/17462 [==============================] - 39s 2ms/sample - loss: 0.4448 - acc: 0.7941 - val_loss: 0.4995 - val_acc: 0.7614
# Epoch 8/10
# 17462/17462 [==============================] - 38s 2ms/sample - loss: 0.4155 - acc: 0.8112 - val_loss: 0.5193 - val_acc: 0.7591
# Epoch 9/10
# 17462/17462 [==============================] - 38s 2ms/sample - loss: 0.3991 - acc: 0.8216 - val_loss: 0.5406 - val_acc: 0.7517
# Epoch 10/10
# 17462/17462 [==============================] - 38s 2ms/sample - loss: 0.3789 - acc: 0.8299 - val_loss: 0.4959 - val_acc: 0.7656

# %% [markdown]
# * After having run this, you should have a new directory called logs. We can visualize the initial results from this directory using tensorboard now. Open a console, change to your working directory, and type: tensorboard --logdir=logs/. You should see a notice like: TensorBoard 1.10.0 at http://H-PC:6006 (Press CTRL+C to quit) where "h-pc" probably is whatever your machine's name is. Open a browser and head to this address. You should see something like:

# %% [markdown]
# ## Tensor Board output of Cats-vs-dogs-CNN

# %% [markdown]
# ![Cats-vs-dogs-CNN](https://user-images.githubusercontent.com/49519213/57575946-39117b80-7455-11e9-92a0-52f922bc6837.png)

# %% [markdown]
# * Imp note -Changed the name to NAME = "Cats-vs-dogs-64x2-CNN". Don't forget to do this, or you'll append to your previous model's logs instead by accident and it wont look too good.

# %% [markdown]
# * Conv2d with 64

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

NAME = "Cats-vs-dogs-64x2-CNN"

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

model = Sequential()

model.add(Conv2D(64, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'],
              )

model.fit(X, y,
          batch_size=32,
          epochs=10,
          validation_split=0.3,
          callbacks=[tensorboard])
# Out:
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 12s 663us/sample - loss: 0.6499 - acc: 0.6177 - val_loss: 0.6196 - val_acc: 0.6598
# Epoch 2/10
# 17462/17462 [==============================] - 11s 623us/sample - loss: 0.5674 - acc: 0.7087 - val_loss: 0.5355 - val_acc: 0.7337
# Epoch 3/10
# 17462/17462 [==============================] - 11s 623us/sample - loss: 0.4885 - acc: 0.7638 - val_loss: 0.5152 - val_acc: 0.7465
# Epoch 4/10
# 17462/17462 [==============================] - 11s 623us/sample - loss: 0.4233 - acc: 0.8026 - val_loss: 0.5049 - val_acc: 0.7624
# Epoch 5/10
# 17462/17462 [==============================] - 11s 628us/sample - loss: 0.3499 - acc: 0.8449 - val_loss: 0.5414 - val_acc: 0.7560
# Epoch 6/10
# 17462/17462 [==============================] - 11s 619us/sample - loss: 0.2555 - acc: 0.8933 - val_loss: 0.5595 - val_acc: 0.7610
# Epoch 7/10
# 17462/17462 [==============================] - 11s 619us/sample - loss: 0.1552 - acc: 0.9419 - val_loss: 0.6919 - val_acc: 0.7667
# Epoch 8/10
# 17462/17462 [==============================] - 11s 630us/sample - loss: 0.0843 - acc: 0.9711 - val_loss: 0.8841 - val_acc: 0.7489
# Epoch 9/10
# 17462/17462 [==============================] - 11s 628us/sample - loss: 0.0437 - acc: 0.9868 - val_loss: 1.0415 - val_acc: 0.7547
# Epoch 10/10
# 17462/17462 [==============================] - 11s 620us/sample - loss: 0.0305 - acc: 0.9914 - val_loss: 1.2711 - val_acc: 0.7495

# %% [markdown]
# ## Tensor Board output of Cats-vs-dogs-64x2-CNN

# %% [markdown]
# ![Cats-vs-dogs-64x2-CNN](https://user-images.githubusercontent.com/49519213/57576011-f0f35880-7456-11e9-9b44-534a64efb568.png)

# %% [markdown]
# ##  The most basic things for us to modify are layers and nodes per layer, as well as 0, 1, or 2 dense layers. and we will see the output in Tensor Board

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)

            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())

            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          )

            model.fit(X, y,
                      batch_size=32,
                      epochs=10,
                      validation_split=0.3,
                      callbacks=[tensorboard])
# Out:
# 1-conv-32-nodes-0-dense-1555345219
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 5s 288us/sample - loss: 0.6306 - acc: 0.6461 - val_loss: 0.6015 - val_acc: 0.6769
# Epoch 2/10
# 17462/17462 [==============================] - 5s 260us/sample - loss: 0.5646 - acc: 0.7113 - val_loss: 0.5768 - val_acc: 0.7002
# Epoch 3/10
# 17462/17462 [==============================] - 5s 262us/sample - loss: 0.5310 - acc: 0.7401 - val_loss: 0.5448 - val_acc: 0.7266
# Epoch 4/10
# 17462/17462 [==============================] - 5s 260us/sample - loss: 0.5063 - acc: 0.7560 - val_loss: 0.5454 - val_acc: 0.7277
# Epoch 5/10
# 17462/17462 [==============================] - 5s 262us/sample - loss: 0.4870 - acc: 0.7724 - val_loss: 0.5359 - val_acc: 0.7345
# Epoch 6/10
# 17462/17462 [==============================] - 5s 260us/sample - loss: 0.4738 - acc: 0.7775 - val_loss: 0.5307 - val_acc: 0.7425
# Epoch 7/10
# 17462/17462 [==============================] - 5s 260us/sample - loss: 0.4610 - acc: 0.7858 - val_loss: 0.5311 - val_acc: 0.7440
# Epoch 8/10
# 17462/17462 [==============================] - 4s 257us/sample - loss: 0.4503 - acc: 0.7927 - val_loss: 0.5870 - val_acc: 0.7090
# Epoch 9/10
# 17462/17462 [==============================] - 5s 259us/sample - loss: 0.4382 - acc: 0.7994 - val_loss: 0.5336 - val_acc: 0.7394
# Epoch 10/10
# 17462/17462 [==============================] - 5s 260us/sample - loss: 0.4341 - acc: 0.8019 - val_loss: 0.5363 - val_acc: 0.7385
# 2-conv-32-nodes-0-dense-1555345268
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 6s 345us/sample - loss: 0.6277 - acc: 0.6439 - val_loss: 0.5948 - val_acc: 0.6815
# Epoch 2/10
# 17462/17462 [==============================] - 5s 315us/sample - loss: 0.5478 - acc: 0.7243 - val_loss: 0.5565 - val_acc: 0.7190
# Epoch 3/10
# 17462/17462 [==============================] - 5s 313us/sample - loss: 0.5122 - acc: 0.7491 - val_loss: 0.5191 - val_acc: 0.7476
# Epoch 4/10
# 17462/17462 [==============================] - 5s 312us/sample - loss: 0.4819 - acc: 0.7697 - val_loss: 0.5005 - val_acc: 0.7582
# Epoch 5/10
# 17462/17462 [==============================] - 5s 313us/sample - loss: 0.4681 - acc: 0.7798 - val_loss: 0.5275 - val_acc: 0.7427
# Epoch 6/10
# 17462/17462 [==============================] - 6s 317us/sample - loss: 0.4525 - acc: 0.7875 - val_loss: 0.4830 - val_acc: 0.7680
# Epoch 7/10
# 17462/17462 [==============================] - 5s 312us/sample - loss: 0.4366 - acc: 0.7982 - val_loss: 0.5145 - val_acc: 0.7499
# Epoch 8/10
# 17462/17462 [==============================] - 5s 312us/sample - loss: 0.4258 - acc: 0.8046 - val_loss: 0.4787 - val_acc: 0.7714
# Epoch 9/10
# 17462/17462 [==============================] - 5s 312us/sample - loss: 0.4119 - acc: 0.8138 - val_loss: 0.4888 - val_acc: 0.7696
# Epoch 10/10
# 17462/17462 [==============================] - 5s 314us/sample - loss: 0.4002 - acc: 0.8214 - val_loss: 0.4754 - val_acc: 0.7751
# 3-conv-32-nodes-0-dense-1555345327
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 7s 380us/sample - loss: 0.6535 - acc: 0.6053 - val_loss: 0.6097 - val_acc: 0.6674
# Epoch 2/10
# 17462/17462 [==============================] - 6s 344us/sample - loss: 0.5667 - acc: 0.7122 - val_loss: 0.5569 - val_acc: 0.7149
# Epoch 3/10
# 17462/17462 [==============================] - 6s 343us/sample - loss: 0.5238 - acc: 0.7427 - val_loss: 0.5755 - val_acc: 0.6896
# Epoch 4/10
# 17462/17462 [==============================] - 6s 345us/sample - loss: 0.4909 - acc: 0.7630 - val_loss: 0.5073 - val_acc: 0.7560
# Epoch 5/10
# 17462/17462 [==============================] - 6s 344us/sample - loss: 0.4666 - acc: 0.7768 - val_loss: 0.4973 - val_acc: 0.7691
# Epoch 6/10
# 17462/17462 [==============================] - 6s 342us/sample - loss: 0.4416 - acc: 0.7950 - val_loss: 0.4743 - val_acc: 0.7747
# Epoch 7/10
# 17462/17462 [==============================] - 6s 344us/sample - loss: 0.4257 - acc: 0.8056 - val_loss: 0.4958 - val_acc: 0.7647
# Epoch 8/10
# 17462/17462 [==============================] - 6s 344us/sample - loss: 0.4120 - acc: 0.8110 - val_loss: 0.4664 - val_acc: 0.7786
# Epoch 9/10
# 17462/17462 [==============================] - 6s 345us/sample - loss: 0.3931 - acc: 0.8246 - val_loss: 0.4625 - val_acc: 0.7881
# Epoch 10/10
# 17462/17462 [==============================] - 6s 345us/sample - loss: 0.3785 - acc: 0.8305 - val_loss: 0.4560 - val_acc: 0.7893
# 1-conv-64-nodes-0-dense-1555345392
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 7s 374us/sample - loss: 0.6176 - acc: 0.6565 - val_loss: 0.5980 - val_acc: 0.6821
# Epoch 2/10
# 17462/17462 [==============================] - 6s 334us/sample - loss: 0.5415 - acc: 0.7335 - val_loss: 0.5505 - val_acc: 0.7211
# Epoch 3/10
# 17462/17462 [==============================] - 6s 334us/sample - loss: 0.5070 - acc: 0.7547 - val_loss: 0.5564 - val_acc: 0.7181
# Epoch 4/10
# 17462/17462 [==============================] - 6s 334us/sample - loss: 0.4819 - acc: 0.7728 - val_loss: 0.5455 - val_acc: 0.7298
# Epoch 5/10
# 17462/17462 [==============================] - 6s 331us/sample - loss: 0.4609 - acc: 0.7845 - val_loss: 0.5302 - val_acc: 0.7429
# Epoch 6/10
# 17462/17462 [==============================] - 6s 332us/sample - loss: 0.4421 - acc: 0.7938 - val_loss: 0.5345 - val_acc: 0.7360
# Epoch 7/10
# 17462/17462 [==============================] - 6s 331us/sample - loss: 0.4267 - acc: 0.8023 - val_loss: 0.5417 - val_acc: 0.7393
# Epoch 8/10
# 17462/17462 [==============================] - 6s 331us/sample - loss: 0.4111 - acc: 0.8145 - val_loss: 0.5414 - val_acc: 0.7412
# Epoch 9/10
# 17462/17462 [==============================] - 6s 333us/sample - loss: 0.3949 - acc: 0.8201 - val_loss: 0.5666 - val_acc: 0.7322
# Epoch 10/10
# 17462/17462 [==============================] - 6s 332us/sample - loss: 0.3831 - acc: 0.8303 - val_loss: 0.5589 - val_acc: 0.7341
# 2-conv-64-nodes-0-dense-1555345455
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 8s 448us/sample - loss: 0.6289 - acc: 0.6390 - val_loss: 0.5939 - val_acc: 0.6921
# Epoch 2/10
# 17462/17462 [==============================] - 7s 398us/sample - loss: 0.5418 - acc: 0.7263 - val_loss: 0.5357 - val_acc: 0.7317
# Epoch 3/10
# 17462/17462 [==============================] - 7s 397us/sample - loss: 0.4950 - acc: 0.7601 - val_loss: 0.5409 - val_acc: 0.7243
# Epoch 4/10
# 17462/17462 [==============================] - 7s 396us/sample - loss: 0.4611 - acc: 0.7822 - val_loss: 0.5272 - val_acc: 0.7350
# Epoch 5/10
# 17462/17462 [==============================] - 7s 393us/sample - loss: 0.4387 - acc: 0.7961 - val_loss: 0.4796 - val_acc: 0.7722
# Epoch 6/10
# 17462/17462 [==============================] - 7s 391us/sample - loss: 0.4173 - acc: 0.8123 - val_loss: 0.4660 - val_acc: 0.7785
# Epoch 7/10
# 17462/17462 [==============================] - 7s 392us/sample - loss: 0.3963 - acc: 0.8231 - val_loss: 0.4490 - val_acc: 0.7941
# Epoch 8/10
# 17462/17462 [==============================] - 7s 392us/sample - loss: 0.3787 - acc: 0.8315 - val_loss: 0.4623 - val_acc: 0.7841
# Epoch 9/10
# 17462/17462 [==============================] - 7s 393us/sample - loss: 0.3603 - acc: 0.8404 - val_loss: 0.4773 - val_acc: 0.7801
# Epoch 10/10
# 17462/17462 [==============================] - 7s 394us/sample - loss: 0.3436 - acc: 0.8517 - val_loss: 0.4666 - val_acc: 0.7831
# 3-conv-64-nodes-0-dense-1555345529
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 9s 525us/sample - loss: 0.6553 - acc: 0.6015 - val_loss: 0.6118 - val_acc: 0.6615
# Epoch 2/10
# 17462/17462 [==============================] - 8s 475us/sample - loss: 0.5651 - acc: 0.7128 - val_loss: 0.5433 - val_acc: 0.7226
# Epoch 3/10
# 17462/17462 [==============================] - 8s 463us/sample - loss: 0.5038 - acc: 0.7555 - val_loss: 0.5296 - val_acc: 0.7349
# Epoch 4/10
# 17462/17462 [==============================] - 8s 460us/sample - loss: 0.4644 - acc: 0.7800 - val_loss: 0.4845 - val_acc: 0.7708
# Epoch 5/10
# 17462/17462 [==============================] - 8s 459us/sample - loss: 0.4341 - acc: 0.7990 - val_loss: 0.4714 - val_acc: 0.7765
# Epoch 6/10
# 17462/17462 [==============================] - 8s 460us/sample - loss: 0.4142 - acc: 0.8095 - val_loss: 0.4439 - val_acc: 0.7894
# Epoch 7/10
# 17462/17462 [==============================] - 8s 457us/sample - loss: 0.3912 - acc: 0.8217 - val_loss: 0.4381 - val_acc: 0.7985
# Epoch 8/10
# 17462/17462 [==============================] - 8s 455us/sample - loss: 0.3718 - acc: 0.8331 - val_loss: 0.4480 - val_acc: 0.7889
# Epoch 9/10
# 17462/17462 [==============================] - 8s 455us/sample - loss: 0.3490 - acc: 0.8447 - val_loss: 0.4425 - val_acc: 0.7912
# Epoch 10/10
# 17462/17462 [==============================] - 8s 452us/sample - loss: 0.3244 - acc: 0.8591 - val_loss: 0.4744 - val_acc: 0.7847
# 1-conv-128-nodes-0-dense-1555345616
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 9s 503us/sample - loss: 0.6254 - acc: 0.6526 - val_loss: 0.5780 - val_acc: 0.6988
# Epoch 2/10
# 17462/17462 [==============================] - 8s 455us/sample - loss: 0.5466 - acc: 0.7294 - val_loss: 0.5611 - val_acc: 0.7213
# Epoch 3/10
# 17462/17462 [==============================] - 8s 458us/sample - loss: 0.5048 - acc: 0.7595 - val_loss: 0.5546 - val_acc: 0.7130
# Epoch 4/10
# 17462/17462 [==============================] - 8s 458us/sample - loss: 0.4797 - acc: 0.7680 - val_loss: 0.5487 - val_acc: 0.7278
# Epoch 5/10
# 17462/17462 [==============================] - 8s 457us/sample - loss: 0.4566 - acc: 0.7870 - val_loss: 0.5362 - val_acc: 0.7381
# Epoch 6/10
# 17462/17462 [==============================] - 8s 457us/sample - loss: 0.4305 - acc: 0.8027 - val_loss: 0.5418 - val_acc: 0.7402
# Epoch 7/10
# 17462/17462 [==============================] - 8s 460us/sample - loss: 0.4085 - acc: 0.8173 - val_loss: 0.5682 - val_acc: 0.7251
# Epoch 8/10
# 17462/17462 [==============================] - 8s 457us/sample - loss: 0.3885 - acc: 0.8275 - val_loss: 0.5644 - val_acc: 0.7373
# Epoch 9/10
# 17462/17462 [==============================] - 8s 458us/sample - loss: 0.3686 - acc: 0.8361 - val_loss: 0.5634 - val_acc: 0.7330
# Epoch 10/10
# 17462/17462 [==============================] - 8s 459us/sample - loss: 0.3472 - acc: 0.8510 - val_loss: 0.5659 - val_acc: 0.7330
# 2-conv-128-nodes-0-dense-1555345702
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 12s 666us/sample - loss: 0.6228 - acc: 0.6424 - val_loss: 0.5617 - val_acc: 0.7147
# Epoch 2/10
# 17462/17462 [==============================] - 11s 612us/sample - loss: 0.5248 - acc: 0.7421 - val_loss: 0.5243 - val_acc: 0.7397
# Epoch 3/10
# 17462/17462 [==============================] - 11s 612us/sample - loss: 0.4788 - acc: 0.7727 - val_loss: 0.5001 - val_acc: 0.7572
# Epoch 4/10
# 17462/17462 [==============================] - 11s 613us/sample - loss: 0.4489 - acc: 0.7901 - val_loss: 0.5079 - val_acc: 0.7556
# Epoch 5/10
# 17462/17462 [==============================] - 11s 609us/sample - loss: 0.4257 - acc: 0.8051 - val_loss: 0.4729 - val_acc: 0.7789
# Epoch 6/10
# 17462/17462 [==============================] - 11s 610us/sample - loss: 0.4019 - acc: 0.8198 - val_loss: 0.4613 - val_acc: 0.7890
# Epoch 7/10
# 17462/17462 [==============================] - 11s 611us/sample - loss: 0.3746 - acc: 0.8324 - val_loss: 0.4602 - val_acc: 0.7859
# Epoch 8/10
# 17462/17462 [==============================] - 11s 612us/sample - loss: 0.3591 - acc: 0.8394 - val_loss: 0.4655 - val_acc: 0.7829
# Epoch 9/10
# 17462/17462 [==============================] - 11s 607us/sample - loss: 0.3337 - acc: 0.8547 - val_loss: 0.4682 - val_acc: 0.7851
# Epoch 10/10
# 17462/17462 [==============================] - 11s 611us/sample - loss: 0.3137 - acc: 0.8638 - val_loss: 0.4671 - val_acc: 0.7846
# 3-conv-128-nodes-0-dense-1555345815
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 13s 750us/sample - loss: 0.6690 - acc: 0.5788 - val_loss: 0.6535 - val_acc: 0.6142
# Epoch 2/10
# 17462/17462 [==============================] - 12s 701us/sample - loss: 0.5672 - acc: 0.7099 - val_loss: 0.5279 - val_acc: 0.7384
# Epoch 3/10
# 17462/17462 [==============================] - 12s 701us/sample - loss: 0.4957 - acc: 0.7629 - val_loss: 0.4834 - val_acc: 0.7706
# Epoch 4/10
# 17462/17462 [==============================] - 12s 698us/sample - loss: 0.4481 - acc: 0.7883 - val_loss: 0.4716 - val_acc: 0.7781
# Epoch 5/10
# 17462/17462 [==============================] - 12s 700us/sample - loss: 0.4093 - acc: 0.8100 - val_loss: 0.4387 - val_acc: 0.7996
# Epoch 6/10
# 17462/17462 [==============================] - 12s 698us/sample - loss: 0.3751 - acc: 0.8303 - val_loss: 0.4633 - val_acc: 0.7858
# Epoch 7/10
# 17462/17462 [==============================] - 12s 699us/sample - loss: 0.3400 - acc: 0.8529 - val_loss: 0.4465 - val_acc: 0.7956
# Epoch 8/10
# 17462/17462 [==============================] - 12s 701us/sample - loss: 0.3103 - acc: 0.8639 - val_loss: 0.4462 - val_acc: 0.7944
# Epoch 9/10
# 17462/17462 [==============================] - 12s 697us/sample - loss: 0.2782 - acc: 0.8805 - val_loss: 0.4486 - val_acc: 0.8077
# Epoch 10/10
# 17462/17462 [==============================] - 12s 700us/sample - loss: 0.2509 - acc: 0.8957 - val_loss: 0.4301 - val_acc: 0.8103
# 1-conv-32-nodes-1-dense-1555345944
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 6s 339us/sample - loss: 0.6199 - acc: 0.6503 - val_loss: 0.5680 - val_acc: 0.7107
# Epoch 2/10
# 17462/17462 [==============================] - 5s 292us/sample - loss: 0.5367 - acc: 0.7390 - val_loss: 0.5506 - val_acc: 0.7239
# Epoch 3/10
# 17462/17462 [==============================] - 5s 292us/sample - loss: 0.4947 - acc: 0.7642 - val_loss: 0.5332 - val_acc: 0.7393
# Epoch 4/10
# 17462/17462 [==============================] - 5s 292us/sample - loss: 0.4637 - acc: 0.7821 - val_loss: 0.5542 - val_acc: 0.7217
# Epoch 5/10
# 17462/17462 [==============================] - 5s 291us/sample - loss: 0.4331 - acc: 0.8004 - val_loss: 0.5488 - val_acc: 0.7238
# Epoch 6/10
# 17462/17462 [==============================] - 5s 290us/sample - loss: 0.4075 - acc: 0.8143 - val_loss: 0.5645 - val_acc: 0.7318
# Epoch 7/10
# 17462/17462 [==============================] - 5s 291us/sample - loss: 0.3764 - acc: 0.8328 - val_loss: 0.5628 - val_acc: 0.7358
# Epoch 8/10
# 17462/17462 [==============================] - 5s 293us/sample - loss: 0.3459 - acc: 0.8497 - val_loss: 0.5861 - val_acc: 0.7282
# Epoch 9/10
# 17462/17462 [==============================] - 5s 291us/sample - loss: 0.3122 - acc: 0.8651 - val_loss: 0.6120 - val_acc: 0.7214
# Epoch 10/10
# 17462/17462 [==============================] - 5s 291us/sample - loss: 0.2788 - acc: 0.8808 - val_loss: 0.6295 - val_acc: 0.7281
# 2-conv-32-nodes-1-dense-1555346002
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 7s 382us/sample - loss: 0.6262 - acc: 0.6401 - val_loss: 0.5630 - val_acc: 0.7111
# Epoch 2/10
# 17462/17462 [==============================] - 6s 340us/sample - loss: 0.5323 - acc: 0.7390 - val_loss: 0.5247 - val_acc: 0.7477
# Epoch 3/10
# 17462/17462 [==============================] - 6s 339us/sample - loss: 0.4936 - acc: 0.7638 - val_loss: 0.5158 - val_acc: 0.7523
# Epoch 4/10
# 17462/17462 [==============================] - 6s 340us/sample - loss: 0.4705 - acc: 0.7785 - val_loss: 0.4983 - val_acc: 0.7610
# Epoch 5/10
# 17462/17462 [==============================] - 6s 340us/sample - loss: 0.4463 - acc: 0.7928 - val_loss: 0.4968 - val_acc: 0.7595
# Epoch 6/10
# 17462/17462 [==============================] - 6s 337us/sample - loss: 0.4284 - acc: 0.8033 - val_loss: 0.4803 - val_acc: 0.7782
# Epoch 7/10
# 17462/17462 [==============================] - 6s 339us/sample - loss: 0.4009 - acc: 0.8181 - val_loss: 0.4729 - val_acc: 0.7759
# Epoch 8/10
# 17462/17462 [==============================] - 6s 338us/sample - loss: 0.3801 - acc: 0.8302 - val_loss: 0.4778 - val_acc: 0.7783
# Epoch 9/10
# 17462/17462 [==============================] - 6s 339us/sample - loss: 0.3598 - acc: 0.8409 - val_loss: 0.4777 - val_acc: 0.7807
# Epoch 10/10
# 17462/17462 [==============================] - 6s 340us/sample - loss: 0.3483 - acc: 0.8427 - val_loss: 0.4652 - val_acc: 0.7900
# 3-conv-32-nodes-1-dense-1555346069
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 7s 417us/sample - loss: 0.6572 - acc: 0.5962 - val_loss: 0.6519 - val_acc: 0.6093
# Epoch 2/10
# 17462/17462 [==============================] - 6s 368us/sample - loss: 0.5666 - acc: 0.7107 - val_loss: 0.5506 - val_acc: 0.7207
# Epoch 3/10
# 17462/17462 [==============================] - 6s 369us/sample - loss: 0.5121 - acc: 0.7464 - val_loss: 0.5144 - val_acc: 0.7433
# Epoch 4/10
# 17462/17462 [==============================] - 6s 368us/sample - loss: 0.4778 - acc: 0.7728 - val_loss: 0.4806 - val_acc: 0.7684
# Epoch 5/10
# 17462/17462 [==============================] - 6s 368us/sample - loss: 0.4486 - acc: 0.7894 - val_loss: 0.4771 - val_acc: 0.7751
# Epoch 6/10
# 17462/17462 [==============================] - 6s 368us/sample - loss: 0.4224 - acc: 0.8074 - val_loss: 0.4927 - val_acc: 0.7663
# Epoch 7/10
# 17462/17462 [==============================] - 6s 369us/sample - loss: 0.3956 - acc: 0.8198 - val_loss: 0.4577 - val_acc: 0.7850
# Epoch 8/10
# 17462/17462 [==============================] - 6s 369us/sample - loss: 0.3714 - acc: 0.8321 - val_loss: 0.4935 - val_acc: 0.7815
# Epoch 9/10
# 17462/17462 [==============================] - 6s 367us/sample - loss: 0.3466 - acc: 0.8450 - val_loss: 0.4523 - val_acc: 0.7969
# Epoch 10/10
# 17462/17462 [==============================] - 6s 370us/sample - loss: 0.3260 - acc: 0.8543 - val_loss: 0.4500 - val_acc: 0.7926
# 1-conv-64-nodes-1-dense-1555346141
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 7s 422us/sample - loss: 0.6076 - acc: 0.6728 - val_loss: 0.5870 - val_acc: 0.6856
# Epoch 2/10
# 17462/17462 [==============================] - 6s 364us/sample - loss: 0.5194 - acc: 0.7480 - val_loss: 0.5494 - val_acc: 0.7181
# Epoch 3/10
# 17462/17462 [==============================] - 6s 366us/sample - loss: 0.4732 - acc: 0.7739 - val_loss: 0.5392 - val_acc: 0.7346
# Epoch 4/10
# 17462/17462 [==============================] - 6s 366us/sample - loss: 0.4215 - acc: 0.8048 - val_loss: 0.5373 - val_acc: 0.7414
# Epoch 5/10
# 17462/17462 [==============================] - 6s 364us/sample - loss: 0.3748 - acc: 0.8301 - val_loss: 0.5678 - val_acc: 0.7384
# Epoch 6/10
# 17462/17462 [==============================] - 6s 365us/sample - loss: 0.3147 - acc: 0.8626 - val_loss: 0.5891 - val_acc: 0.7328
# Epoch 7/10
# 17462/17462 [==============================] - 6s 368us/sample - loss: 0.2505 - acc: 0.8991 - val_loss: 0.6512 - val_acc: 0.7364
# Epoch 8/10
# 17462/17462 [==============================] - 6s 366us/sample - loss: 0.1914 - acc: 0.9257 - val_loss: 0.6998 - val_acc: 0.7377
# Epoch 9/10
# 17462/17462 [==============================] - 6s 366us/sample - loss: 0.1379 - acc: 0.9515 - val_loss: 0.8788 - val_acc: 0.7237
# Epoch 10/10
# 17462/17462 [==============================] - 6s 367us/sample - loss: 0.0985 - acc: 0.9680 - val_loss: 0.8269 - val_acc: 0.7215
# 2-conv-64-nodes-1-dense-1555346214
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 9s 510us/sample - loss: 0.6247 - acc: 0.6450 - val_loss: 0.5571 - val_acc: 0.7191
# Epoch 2/10
# 17462/17462 [==============================] - 8s 441us/sample - loss: 0.5270 - acc: 0.7397 - val_loss: 0.5384 - val_acc: 0.7262
# Epoch 3/10
# 17462/17462 [==============================] - 8s 438us/sample - loss: 0.4792 - acc: 0.7697 - val_loss: 0.4884 - val_acc: 0.7612
# Epoch 4/10
# 17462/17462 [==============================] - 8s 438us/sample - loss: 0.4363 - acc: 0.7973 - val_loss: 0.5221 - val_acc: 0.7441
# Epoch 5/10
# 17462/17462 [==============================] - 8s 437us/sample - loss: 0.3991 - acc: 0.8183 - val_loss: 0.4903 - val_acc: 0.7651
# Epoch 6/10
# 17462/17462 [==============================] - 8s 435us/sample - loss: 0.3598 - acc: 0.8387 - val_loss: 0.4689 - val_acc: 0.7787
# Epoch 7/10
# 17462/17462 [==============================] - 8s 435us/sample - loss: 0.3225 - acc: 0.8596 - val_loss: 0.4895 - val_acc: 0.7762
# Epoch 8/10
# 17462/17462 [==============================] - 8s 433us/sample - loss: 0.2803 - acc: 0.8811 - val_loss: 0.5180 - val_acc: 0.7726
# Epoch 9/10
# 17462/17462 [==============================] - 8s 433us/sample - loss: 0.2402 - acc: 0.9000 - val_loss: 0.5205 - val_acc: 0.7853
# Epoch 10/10
# 17462/17462 [==============================] - 8s 431us/sample - loss: 0.1962 - acc: 0.9195 - val_loss: 0.5556 - val_acc: 0.7896
# 3-conv-64-nodes-1-dense-1555346299
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 10s 583us/sample - loss: 0.6435 - acc: 0.6202 - val_loss: 0.5713 - val_acc: 0.7066
# Epoch 2/10
# 17462/17462 [==============================] - 9s 520us/sample - loss: 0.5324 - acc: 0.7349 - val_loss: 0.5036 - val_acc: 0.7531
# Epoch 3/10
# 17462/17462 [==============================] - 9s 519us/sample - loss: 0.4666 - acc: 0.7788 - val_loss: 0.4688 - val_acc: 0.7759
# Epoch 4/10
# 17462/17462 [==============================] - 9s 513us/sample - loss: 0.4187 - acc: 0.8044 - val_loss: 0.4700 - val_acc: 0.7714
# Epoch 5/10
# 17462/17462 [==============================] - 9s 513us/sample - loss: 0.3787 - acc: 0.8298 - val_loss: 0.4353 - val_acc: 0.8004
# Epoch 6/10
# 17462/17462 [==============================] - 9s 511us/sample - loss: 0.3423 - acc: 0.8481 - val_loss: 0.4486 - val_acc: 0.7906
# Epoch 7/10
# 17462/17462 [==============================] - 9s 509us/sample - loss: 0.3069 - acc: 0.8650 - val_loss: 0.4340 - val_acc: 0.8108
# Epoch 8/10
# 17462/17462 [==============================] - 9s 508us/sample - loss: 0.2731 - acc: 0.8829 - val_loss: 0.4590 - val_acc: 0.8076
# Epoch 9/10
# 17462/17462 [==============================] - 9s 508us/sample - loss: 0.2443 - acc: 0.8948 - val_loss: 0.4869 - val_acc: 0.8064
# Epoch 10/10
# 17462/17462 [==============================] - 9s 508us/sample - loss: 0.2133 - acc: 0.9103 - val_loss: 0.5032 - val_acc: 0.8044
# 1-conv-128-nodes-1-dense-1555346399
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 14s 809us/sample - loss: 0.6172 - acc: 0.6660 - val_loss: 0.5760 - val_acc: 0.7020
# Epoch 2/10
# 17462/17462 [==============================] - 13s 750us/sample - loss: 0.5162 - acc: 0.7481 - val_loss: 0.5371 - val_acc: 0.7337
# Epoch 3/10
# 17462/17462 [==============================] - 13s 750us/sample - loss: 0.4585 - acc: 0.7808 - val_loss: 0.5324 - val_acc: 0.7389
# Epoch 4/10
# 17462/17462 [==============================] - 13s 751us/sample - loss: 0.3967 - acc: 0.8173 - val_loss: 0.5582 - val_acc: 0.7440
# Epoch 5/10
# 17462/17462 [==============================] - 13s 746us/sample - loss: 0.3211 - acc: 0.8611 - val_loss: 0.6240 - val_acc: 0.7253
# Epoch 6/10
# 17462/17462 [==============================] - 13s 749us/sample - loss: 0.2377 - acc: 0.9046 - val_loss: 0.6612 - val_acc: 0.7349
# Epoch 7/10
# 17462/17462 [==============================] - 13s 748us/sample - loss: 0.1541 - acc: 0.9434 - val_loss: 0.7768 - val_acc: 0.7195
# Epoch 8/10
# 17462/17462 [==============================] - 13s 744us/sample - loss: 0.0943 - acc: 0.9698 - val_loss: 0.9238 - val_acc: 0.7296
# Epoch 9/10
# 17462/17462 [==============================] - 13s 751us/sample - loss: 0.0544 - acc: 0.9856 - val_loss: 0.9735 - val_acc: 0.7263
# Epoch 10/10
# 17462/17462 [==============================] - 13s 750us/sample - loss: 0.0389 - acc: 0.9904 - val_loss: 1.1767 - val_acc: 0.7253
# 2-conv-128-nodes-1-dense-1555346539
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 13s 764us/sample - loss: 0.6439 - acc: 0.6242 - val_loss: 0.5848 - val_acc: 0.6978
# Epoch 2/10
# 17462/17462 [==============================] - 12s 700us/sample - loss: 0.5481 - acc: 0.7251 - val_loss: 0.5370 - val_acc: 0.7358
# Epoch 3/10
# 17462/17462 [==============================] - 12s 700us/sample - loss: 0.5033 - acc: 0.7531 - val_loss: 0.5182 - val_acc: 0.7493
# Epoch 4/10
# 17462/17462 [==============================] - 12s 701us/sample - loss: 0.4732 - acc: 0.7781 - val_loss: 0.5134 - val_acc: 0.7595
# Epoch 5/10
# 17462/17462 [==============================] - 12s 700us/sample - loss: 0.4401 - acc: 0.7942 - val_loss: 0.4855 - val_acc: 0.7668
# Epoch 6/10
# 17462/17462 [==============================] - 12s 699us/sample - loss: 0.4117 - acc: 0.8149 - val_loss: 0.4786 - val_acc: 0.7765
# Epoch 7/10
# 17462/17462 [==============================] - 12s 698us/sample - loss: 0.3745 - acc: 0.8330 - val_loss: 0.5170 - val_acc: 0.7670
# Epoch 8/10
# 17462/17462 [==============================] - 12s 702us/sample - loss: 0.3380 - acc: 0.8497 - val_loss: 0.5018 - val_acc: 0.7722
# Epoch 9/10
# 17462/17462 [==============================] - 12s 703us/sample - loss: 0.2988 - acc: 0.8697 - val_loss: 0.5287 - val_acc: 0.7706
# Epoch 10/10
# 17462/17462 [==============================] - 12s 702us/sample - loss: 0.2577 - acc: 0.8917 - val_loss: 0.5377 - val_acc: 0.7739
# 3-conv-128-nodes-1-dense-1555346672
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 14s 804us/sample - loss: 0.6762 - acc: 0.5686 - val_loss: 0.6258 - val_acc: 0.6527
# Epoch 2/10
# 17462/17462 [==============================] - 13s 734us/sample - loss: 0.5795 - acc: 0.6976 - val_loss: 0.5444 - val_acc: 0.7333
# Epoch 3/10
# 17462/17462 [==============================] - 13s 735us/sample - loss: 0.4997 - acc: 0.7579 - val_loss: 0.5336 - val_acc: 0.7334
# Epoch 4/10
# 17462/17462 [==============================] - 13s 735us/sample - loss: 0.4490 - acc: 0.7880 - val_loss: 0.4894 - val_acc: 0.7623
# Epoch 5/10
# 17462/17462 [==============================] - 13s 738us/sample - loss: 0.4014 - acc: 0.8170 - val_loss: 0.4467 - val_acc: 0.7930
# Epoch 6/10
# 17462/17462 [==============================] - 13s 737us/sample - loss: 0.3641 - acc: 0.8372 - val_loss: 0.4469 - val_acc: 0.7994
# Epoch 7/10
# 17462/17462 [==============================] - 13s 737us/sample - loss: 0.3285 - acc: 0.8555 - val_loss: 0.4258 - val_acc: 0.8075
# Epoch 8/10
# 17462/17462 [==============================] - 13s 734us/sample - loss: 0.2862 - acc: 0.8780 - val_loss: 0.4316 - val_acc: 0.8085
# Epoch 9/10
# 17462/17462 [==============================] - 13s 736us/sample - loss: 0.2526 - acc: 0.8953 - val_loss: 0.4816 - val_acc: 0.7946
# Epoch 10/10
# 17462/17462 [==============================] - 13s 736us/sample - loss: 0.2204 - acc: 0.9103 - val_loss: 0.5865 - val_acc: 0.7862
# 1-conv-32-nodes-2-dense-1555346812
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 7s 381us/sample - loss: 0.6231 - acc: 0.6523 - val_loss: 0.5836 - val_acc: 0.6947
# Epoch 2/10
# 17462/17462 [==============================] - 6s 322us/sample - loss: 0.5344 - acc: 0.7346 - val_loss: 0.5481 - val_acc: 0.7217
# Epoch 3/10
# 17462/17462 [==============================] - 6s 318us/sample - loss: 0.4948 - acc: 0.7592 - val_loss: 0.5558 - val_acc: 0.7245
# Epoch 4/10
# 17462/17462 [==============================] - 6s 318us/sample - loss: 0.4634 - acc: 0.7798 - val_loss: 0.5463 - val_acc: 0.7317
# Epoch 5/10
# 17462/17462 [==============================] - 6s 320us/sample - loss: 0.4244 - acc: 0.8044 - val_loss: 0.5935 - val_acc: 0.7154
# Epoch 6/10
# 17462/17462 [==============================] - 6s 322us/sample - loss: 0.3885 - acc: 0.8261 - val_loss: 0.5555 - val_acc: 0.7378
# Epoch 7/10
# 17462/17462 [==============================] - 6s 318us/sample - loss: 0.3517 - acc: 0.8423 - val_loss: 0.6033 - val_acc: 0.7304
# Epoch 8/10
# 17462/17462 [==============================] - 6s 316us/sample - loss: 0.3032 - acc: 0.8687 - val_loss: 0.6867 - val_acc: 0.7281
# Epoch 9/10
# 17462/17462 [==============================] - 6s 318us/sample - loss: 0.2630 - acc: 0.8880 - val_loss: 0.7443 - val_acc: 0.7209
# Epoch 10/10
# 17462/17462 [==============================] - 6s 318us/sample - loss: 0.2200 - acc: 0.9101 - val_loss: 0.8202 - val_acc: 0.7234
# 2-conv-32-nodes-2-dense-1555346879
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 8s 432us/sample - loss: 0.6265 - acc: 0.6404 - val_loss: 0.5713 - val_acc: 0.7096
# Epoch 2/10
# 17462/17462 [==============================] - 6s 363us/sample - loss: 0.5248 - acc: 0.7418 - val_loss: 0.5070 - val_acc: 0.7535
# Epoch 3/10
# 17462/17462 [==============================] - 6s 363us/sample - loss: 0.4817 - acc: 0.7697 - val_loss: 0.4935 - val_acc: 0.7638
# Epoch 4/10
# 17462/17462 [==============================] - 6s 361us/sample - loss: 0.4540 - acc: 0.7864 - val_loss: 0.5205 - val_acc: 0.7541
# Epoch 5/10
# 17462/17462 [==============================] - 6s 362us/sample - loss: 0.4299 - acc: 0.7991 - val_loss: 0.4926 - val_acc: 0.7723
# Epoch 6/10
# 17462/17462 [==============================] - 6s 361us/sample - loss: 0.4009 - acc: 0.8175 - val_loss: 0.4757 - val_acc: 0.7807
# Epoch 7/10
# 17462/17462 [==============================] - 6s 362us/sample - loss: 0.3700 - acc: 0.8324 - val_loss: 0.4754 - val_acc: 0.7823
# Epoch 8/10
# 17462/17462 [==============================] - 6s 363us/sample - loss: 0.3394 - acc: 0.8476 - val_loss: 0.5001 - val_acc: 0.7651
# Epoch 9/10
# 17462/17462 [==============================] - 6s 362us/sample - loss: 0.3062 - acc: 0.8655 - val_loss: 0.5285 - val_acc: 0.7723
# Epoch 10/10
# 17462/17462 [==============================] - 6s 361us/sample - loss: 0.2714 - acc: 0.8834 - val_loss: 0.5588 - val_acc: 0.7698
# 3-conv-32-nodes-2-dense-1555346954
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 8s 467us/sample - loss: 0.6682 - acc: 0.5833 - val_loss: 0.6328 - val_acc: 0.6525
# Epoch 2/10
# 17462/17462 [==============================] - 7s 396us/sample - loss: 0.5843 - acc: 0.6899 - val_loss: 0.5444 - val_acc: 0.7213
# Epoch 3/10
# 17462/17462 [==============================] - 7s 396us/sample - loss: 0.5110 - acc: 0.7527 - val_loss: 0.5015 - val_acc: 0.7565
# Epoch 4/10
# 17462/17462 [==============================] - 7s 395us/sample - loss: 0.4729 - acc: 0.7755 - val_loss: 0.4845 - val_acc: 0.7696
# Epoch 5/10
# 17462/17462 [==============================] - 7s 397us/sample - loss: 0.4432 - acc: 0.7933 - val_loss: 0.4553 - val_acc: 0.7857
# Epoch 6/10
# 17462/17462 [==============================] - 7s 394us/sample - loss: 0.4077 - acc: 0.8096 - val_loss: 0.5202 - val_acc: 0.7394
# Epoch 7/10
# 17462/17462 [==============================] - 7s 395us/sample - loss: 0.3818 - acc: 0.8286 - val_loss: 0.4855 - val_acc: 0.7795
# Epoch 8/10
# 17462/17462 [==============================] - 7s 395us/sample - loss: 0.3594 - acc: 0.8383 - val_loss: 0.4440 - val_acc: 0.7992
# Epoch 9/10
# 17462/17462 [==============================] - 7s 394us/sample - loss: 0.3339 - acc: 0.8540 - val_loss: 0.4931 - val_acc: 0.7765
# Epoch 10/10
# 17462/17462 [==============================] - 7s 395us/sample - loss: 0.3175 - acc: 0.8612 - val_loss: 0.4618 - val_acc: 0.7949
# 1-conv-64-nodes-2-dense-1555347036
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 8s 476us/sample - loss: 0.6176 - acc: 0.6503 - val_loss: 0.6016 - val_acc: 0.6746
# Epoch 2/10
# 17462/17462 [==============================] - 7s 395us/sample - loss: 0.5256 - acc: 0.7394 - val_loss: 0.5352 - val_acc: 0.7338
# Epoch 3/10
# 17462/17462 [==============================] - 7s 394us/sample - loss: 0.4636 - acc: 0.7821 - val_loss: 0.5472 - val_acc: 0.7326
# Epoch 4/10
# 17462/17462 [==============================] - 7s 397us/sample - loss: 0.4101 - acc: 0.8102 - val_loss: 0.5523 - val_acc: 0.7394
# Epoch 5/10
# 17462/17462 [==============================] - 7s 397us/sample - loss: 0.3437 - acc: 0.8479 - val_loss: 0.5733 - val_acc: 0.7297
# Epoch 6/10
# 17462/17462 [==============================] - 7s 397us/sample - loss: 0.2711 - acc: 0.8850 - val_loss: 0.6528 - val_acc: 0.7199
# Epoch 7/10
# 17462/17462 [==============================] - 7s 397us/sample - loss: 0.1972 - acc: 0.9200 - val_loss: 0.7763 - val_acc: 0.7242
# Epoch 8/10
# 17462/17462 [==============================] - 7s 398us/sample - loss: 0.1310 - acc: 0.9475 - val_loss: 0.9292 - val_acc: 0.7145
# Epoch 9/10
# 17462/17462 [==============================] - 7s 395us/sample - loss: 0.0826 - acc: 0.9701 - val_loss: 1.0789 - val_acc: 0.7207
# Epoch 10/10
# 17462/17462 [==============================] - 7s 397us/sample - loss: 0.0618 - acc: 0.9784 - val_loss: 1.3186 - val_acc: 0.7179
# 2-conv-64-nodes-2-dense-1555347119
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 10s 590us/sample - loss: 0.6287 - acc: 0.6319 - val_loss: 0.5746 - val_acc: 0.7028
# Epoch 2/10
# 17462/17462 [==============================] - 9s 508us/sample - loss: 0.5186 - acc: 0.7465 - val_loss: 0.5510 - val_acc: 0.7233
# Epoch 3/10
# 17462/17462 [==============================] - 9s 497us/sample - loss: 0.4701 - acc: 0.7811 - val_loss: 0.4881 - val_acc: 0.7690
# Epoch 4/10
# 17462/17462 [==============================] - 9s 498us/sample - loss: 0.4247 - acc: 0.8047 - val_loss: 0.4703 - val_acc: 0.7790
# Epoch 5/10
# 17462/17462 [==============================] - 9s 495us/sample - loss: 0.3890 - acc: 0.8272 - val_loss: 0.5131 - val_acc: 0.7642
# Epoch 6/10
# 17462/17462 [==============================] - 9s 495us/sample - loss: 0.3464 - acc: 0.8469 - val_loss: 0.5190 - val_acc: 0.7682
# Epoch 7/10
# 17462/17462 [==============================] - 9s 497us/sample - loss: 0.3095 - acc: 0.8634 - val_loss: 0.4862 - val_acc: 0.7757
# Epoch 8/10
# 17462/17462 [==============================] - 9s 497us/sample - loss: 0.2575 - acc: 0.8919 - val_loss: 0.5787 - val_acc: 0.7809
# Epoch 9/10
# 17462/17462 [==============================] - 9s 496us/sample - loss: 0.2150 - acc: 0.9118 - val_loss: 0.5917 - val_acc: 0.7723
# Epoch 10/10
# 17462/17462 [==============================] - 9s 492us/sample - loss: 0.1687 - acc: 0.9325 - val_loss: 0.6919 - val_acc: 0.7660
# 3-conv-64-nodes-2-dense-1555347220
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 11s 645us/sample - loss: 0.6596 - acc: 0.5897 - val_loss: 0.6070 - val_acc: 0.6796
# Epoch 2/10
# 17462/17462 [==============================] - 10s 549us/sample - loss: 0.5597 - acc: 0.7109 - val_loss: 0.5695 - val_acc: 0.6983
# Epoch 3/10
# 17462/17462 [==============================] - 10s 546us/sample - loss: 0.4853 - acc: 0.7648 - val_loss: 0.4815 - val_acc: 0.7714
# Epoch 4/10
# 17462/17462 [==============================] - 10s 549us/sample - loss: 0.4318 - acc: 0.8012 - val_loss: 0.4726 - val_acc: 0.7728
# Epoch 5/10
# 17462/17462 [==============================] - 10s 546us/sample - loss: 0.3938 - acc: 0.8216 - val_loss: 0.4387 - val_acc: 0.7950
# Epoch 6/10
# 17462/17462 [==============================] - 10s 544us/sample - loss: 0.3528 - acc: 0.8421 - val_loss: 0.4335 - val_acc: 0.7966
# Epoch 7/10
# 17462/17462 [==============================] - 10s 545us/sample - loss: 0.3190 - acc: 0.8596 - val_loss: 0.4527 - val_acc: 0.7965
# Epoch 8/10
# 17462/17462 [==============================] - 9s 543us/sample - loss: 0.2861 - acc: 0.8744 - val_loss: 0.5424 - val_acc: 0.7643
# Epoch 9/10
# 17462/17462 [==============================] - 10s 544us/sample - loss: 0.2486 - acc: 0.8969 - val_loss: 0.4809 - val_acc: 0.8005
# Epoch 10/10
# 17462/17462 [==============================] - 10s 547us/sample - loss: 0.2182 - acc: 0.9094 - val_loss: 0.4695 - val_acc: 0.8105
# 1-conv-128-nodes-2-dense-1555347330
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 15s 862us/sample - loss: 0.6092 - acc: 0.6634 - val_loss: 0.5992 - val_acc: 0.6764
# Epoch 2/10
# 17462/17462 [==============================] - 14s 777us/sample - loss: 0.5127 - acc: 0.7479 - val_loss: 0.5348 - val_acc: 0.7272
# Epoch 3/10
# 17462/17462 [==============================] - 14s 777us/sample - loss: 0.4438 - acc: 0.7907 - val_loss: 0.5570 - val_acc: 0.7328
# Epoch 4/10
# 17462/17462 [==============================] - 13s 773us/sample - loss: 0.3712 - acc: 0.8296 - val_loss: 0.6009 - val_acc: 0.7374
# Epoch 5/10
# 17462/17462 [==============================] - 14s 773us/sample - loss: 0.2784 - acc: 0.8775 - val_loss: 0.6677 - val_acc: 0.7189
# Epoch 6/10
# 17462/17462 [==============================] - 14s 775us/sample - loss: 0.1809 - acc: 0.9272 - val_loss: 0.8762 - val_acc: 0.7254
# Epoch 7/10
# 17462/17462 [==============================] - 14s 774us/sample - loss: 0.1050 - acc: 0.9609 - val_loss: 1.0171 - val_acc: 0.7171
# Epoch 8/10
# 17462/17462 [==============================] - 14s 782us/sample - loss: 0.0684 - acc: 0.9762 - val_loss: 1.1233 - val_acc: 0.7051
# Epoch 9/10
# 17462/17462 [==============================] - 14s 775us/sample - loss: 0.0474 - acc: 0.9841 - val_loss: 1.4811 - val_acc: 0.7235
# Epoch 10/10
# 17462/17462 [==============================] - 14s 775us/sample - loss: 0.0514 - acc: 0.9833 - val_loss: 1.5213 - val_acc: 0.7135
# 2-conv-128-nodes-2-dense-1555347481
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 14s 815us/sample - loss: 0.6304 - acc: 0.6373 - val_loss: 0.5533 - val_acc: 0.7170
# Epoch 2/10
# 17462/17462 [==============================] - 13s 729us/sample - loss: 0.5134 - acc: 0.7525 - val_loss: 0.5029 - val_acc: 0.7590
# Epoch 3/10
# 17462/17462 [==============================] - 13s 728us/sample - loss: 0.4693 - acc: 0.7747 - val_loss: 0.5001 - val_acc: 0.7480
# Epoch 4/10
# 17462/17462 [==============================] - 13s 728us/sample - loss: 0.4237 - acc: 0.8037 - val_loss: 0.4668 - val_acc: 0.7787
# Epoch 5/10
# 17462/17462 [==============================] - 13s 727us/sample - loss: 0.3831 - acc: 0.8273 - val_loss: 0.5024 - val_acc: 0.7517
# Epoch 6/10
# 17462/17462 [==============================] - 13s 729us/sample - loss: 0.3355 - acc: 0.8494 - val_loss: 0.5043 - val_acc: 0.7738
# Epoch 7/10
# 17462/17462 [==============================] - 13s 727us/sample - loss: 0.2727 - acc: 0.8847 - val_loss: 0.5507 - val_acc: 0.7639
# Epoch 8/10
# 17462/17462 [==============================] - 13s 728us/sample - loss: 0.2165 - acc: 0.9073 - val_loss: 0.6138 - val_acc: 0.7716
# Epoch 9/10
# 17462/17462 [==============================] - 13s 727us/sample - loss: 0.1546 - acc: 0.9404 - val_loss: 0.7465 - val_acc: 0.7738
# Epoch 10/10
# 17462/17462 [==============================] - 13s 727us/sample - loss: 0.1204 - acc: 0.9533 - val_loss: 0.8432 - val_acc: 0.7707
# 3-conv-128-nodes-2-dense-1555347624
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 15s 855us/sample - loss: 0.6873 - acc: 0.5376 - val_loss: 0.6913 - val_acc: 0.5182
# Epoch 2/10
# 17462/17462 [==============================] - 13s 762us/sample - loss: 0.6289 - acc: 0.6435 - val_loss: 0.6110 - val_acc: 0.6724
# Epoch 3/10
# 17462/17462 [==============================] - 13s 761us/sample - loss: 0.5404 - acc: 0.7253 - val_loss: 0.5404 - val_acc: 0.7210
# Epoch 4/10
# 17462/17462 [==============================] - 13s 765us/sample - loss: 0.4805 - acc: 0.7684 - val_loss: 0.4842 - val_acc: 0.7639
# Epoch 5/10
# 17462/17462 [==============================] - 13s 769us/sample - loss: 0.4341 - acc: 0.7981 - val_loss: 0.4587 - val_acc: 0.7815
# Epoch 6/10
# 17462/17462 [==============================] - 13s 766us/sample - loss: 0.3975 - acc: 0.8171 - val_loss: 0.4489 - val_acc: 0.7944
# Epoch 7/10
# 17462/17462 [==============================] - 13s 766us/sample - loss: 0.3702 - acc: 0.8301 - val_loss: 0.4510 - val_acc: 0.7949
# Epoch 8/10
# 17462/17462 [==============================] - 13s 763us/sample - loss: 0.3360 - acc: 0.8495 - val_loss: 0.4357 - val_acc: 0.8024
# Epoch 9/10
# 17462/17462 [==============================] - 13s 764us/sample - loss: 0.3070 - acc: 0.8665 - val_loss: 0.5320 - val_acc: 0.7747
# Epoch 10/10
# 17462/17462 [==============================] - 13s 764us/sample - loss: 0.2722 - acc: 0.8804 - val_loss: 0.4648 - val_acc: 0.7924

# %% [markdown]
# Tensor Board output of
# * 3 conv, 64 nodes per layer, 0 dense
# * 3 conv, 128 nodes per layer, 0 dense
# * 3 conv, 32 nodes per layer, 0 dense
# * 3 conv, 32 nodes per layer, 2 dense
# * 3 conv, 32 nodes per layer, 1 dense
# * 2 conv, 32 nodes per layer, 0 dense
# * 2 conv, 64 nodes per layer, 0 dense
# * 3 conv, 128 nodes per layer, 1 dense
# * 2 conv, 128 nodes per layer, 0 dense
# * 2 conv, 32 nodes per layer, 1 dense

# %% [markdown]
# ![tensorboard_for_various_layers ](https://user-images.githubusercontent.com/49519213/57575879-ae7c4c80-7453-11e9-9afe-b52863bf40d7.png)

# %% [markdown]
# It could be tempting to take the highest validation accuracy model, but I tend to instead go for the best (lowest) validation loss models. Like I said before, there is some randomness when it comes to models, but you should notice trends.
#
# <br /> For one, I notice that the models with 0 dense layers seemed to do better overall. There are some very successful models with dense layers, but I am going to guess one is likely not needed here.
#
# <br /> So, zooming into the validation accuracy graph, let's check some of the best ones. Here are the top 10:
#
# * 3 conv, 64 nodes per layer, 0 dense
# * 3 conv, 128 nodes per layer, 0 dense
# * 3 conv, 32 nodes per layer, 0 dense
# * 3 conv, 32 nodes per layer, 2 dense
# * 3 conv, 32 nodes per layer, 1 dense
# * 2 conv, 32 nodes per layer, 0 dense
# * 2 conv, 64 nodes per layer, 0 dense
# * 3 conv, 128 nodes per layer, 1 dense
# * 2 conv, 128 nodes per layer, 0 dense
# * 2 conv, 32 nodes per layer, 1 dense
#
#
# From here, I think we can be comfortable with 0 dense, and 3 convolutional layer with 64 nodes as visualizing  from Tensor Boards .As it has good validation accuracy from other layers.

# %%
print(pre) # print the test image
# Out:
# dog.jpg

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0]
layer_sizes = [64]
conv_layers = [3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)

            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())

            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          )

            model.fit(X, y,
                      batch_size=32,
                      epochs=10,
                      validation_split=0.3,
                      callbacks=[tensorboard])

model.save('64x3-CNN.model')
# Out:
# 3-conv-64-nodes-0-dense-1557615690
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 11s 625us/sample - loss: 0.6337 - acc: 0.6299 - val_loss: 0.6267 - val_acc: 0.6485
# Epoch 2/10
# 17462/17462 [==============================] - 11s 606us/sample - loss: 0.5148 - acc: 0.7502 - val_loss: 0.4927 - val_acc: 0.7655
# Epoch 3/10
# 17462/17462 [==============================] - 11s 608us/sample - loss: 0.4514 - acc: 0.7872 - val_loss: 0.4338 - val_acc: 0.8033
# Epoch 4/10
# 17462/17462 [==============================] - 11s 623us/sample - loss: 0.4023 - acc: 0.8161 - val_loss: 0.4080 - val_acc: 0.8192
# Epoch 5/10
# 17462/17462 [==============================] - 11s 622us/sample - loss: 0.3738 - acc: 0.8335 - val_loss: 0.4208 - val_acc: 0.8060
# Epoch 6/10
# 17462/17462 [==============================] - 11s 614us/sample - loss: 0.3332 - acc: 0.8533 - val_loss: 0.3708 - val_acc: 0.8370
# Epoch 7/10
# 17462/17462 [==============================] - 11s 616us/sample - loss: 0.3049 - acc: 0.8690 - val_loss: 0.3602 - val_acc: 0.8449
# Epoch 8/10
# 17462/17462 [==============================] - 11s 602us/sample - loss: 0.2691 - acc: 0.8847 - val_loss: 0.3789 - val_acc: 0.8415
# Epoch 9/10
# 17462/17462 [==============================] - 11s 604us/sample - loss: 0.2421 - acc: 0.8979 - val_loss: 0.3860 - val_acc: 0.8369
# Epoch 10/10
# 17462/17462 [==============================] - 11s 605us/sample - loss: 0.2150 - acc: 0.9107 - val_loss: 0.3952 - val_acc: 0.8430

# %% [markdown]
# ## Tensor Board output of 3-conv-64-nodes-0-dense-1557615690

# %% [markdown]
# ![3-conv-64-nodes-0-dense-](https://user-images.githubusercontent.com/49519213/57576057-eab1ac00-7457-11e9-98b1-5d05241d7486.png)

# %% [markdown]
# ## Prediction on the highest accuracy model 3-conv-64-nodes-0-dense

# %%
import cv2
import tensorflow as tf

CATEGORIES = ["Dog", "Cat"]

pre="dog.jpg"

def prepare(pre):
    IMG_SIZE = 100 # 50 in txt-based
    img_array = cv2.imread(pre, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)


model = tf.keras.models.load_model("64x3-CNN.model")

prediction = model.predict([prepare(pre)])
print(prediction)  # will be a list in a list.
print(CATEGORIES[int(prediction[0][0])])
# Out:
# [[0.]]
# Dog
